# %%
#logistic regression is a technique that is used to solve classification problems
#types of classification
#1.Binary classification  2.multiclass classification

# %%
import pandas as pd
df = pd.read_csv("insurance_data.csv")
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.xlabel('age')
plt.ylabel('bought_insurance')
plt.scatter(df['age'], df['bought_insurance'], color="blue", marker='+')

# %%
#sigmoid or logit function = z = [1/1+(e^-z)] 
#where e is Euler's number = 2.71828
#This function puts the range b/w 0 and 1

# %%
df.shape
# Out:
# (27, 2)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test,Y_train, Y_test = train_test_split(df[['age']], df['bought_insurance'], test_size=0.1)

# %%
X_test
# Out:
#     age
# 20   21
# 3    52
# 22   40

# %%
X_train
# Out:
#     age
# 0    22
# 18   19
# 26   23
# 2    47
# 7    60
# 6    55
# 10   18
# 17   58
# 1    25
# 16   25
# 8    62
# 4    46
# 23   45
# 24   50
# 13   29
# 11   28
# 25   54
# 9    61
# 19   18
# 21   26
# 5    56
# 14   49
# 15   55
# 12   27

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 1, 1], dtype=int64)

# %%
model.score(X_test,Y_test)
# Out:
# 0.6666666666666666
